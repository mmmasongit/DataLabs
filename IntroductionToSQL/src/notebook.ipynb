# %%
# %load_ext sql
# %config SqlMagic.displaylimit = 0
# %sql postgresql://postgres:postgres@localhost:5433/postgres
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# Connecting and switching to connection 'postgresql://postgres:***@localhost:5433/postgres'
